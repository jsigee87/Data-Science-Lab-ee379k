# %%
###############################################
# Make nice header here
#
###############################################


# Insert code Aman 

import numpy as np

y = np.random.randn(1,100)
print(y)
# Out:
# [[ 0.85080249 -0.70734561 -0.33599218 -0.62496946 -1.06455505 -0.44085483
#    0.78477625 -0.1885931   0.26614504  1.08968407  1.50271463  2.29500597
#   -0.22451586 -1.88749528 -0.47529903  0.13081455 -1.97484175 -0.08327907
#    0.10545487  0.91327555  2.57007193  0.86367191 -0.99057559  0.14809594
#   -0.41872119 -0.19243985 -0.6317487  -0.70454547  1.01310514  0.79150805
#   -0.42590524  1.31664165 -0.49810611  0.58106021  0.18908762 -0.9929662
#   -0.76882599  0.58048841  0.5589873  -0.68415671  0.43443178  1.61995018
#   -0.70258833  1.14806989 -1.11225887 -0.71600493  0.32996171  0.18792408
#   -0.4621666   0.01614899 -1.36195533  0.27756801 -0.97834367  1.17273239
#    1.45107112  0.6073108  -0.9615771   1.31815793  0.94552454 -0.75594986
#   -1.34496121  0.9041383   0.8177054  -0.12899472  2.28196175 -0.4453497
#   -0.7157526   0.70805948 -0.62956169 -0.71777513  0.70116477  0.73429815
#   -0.73945176  0.57552314  1.06201145  0.53432808  1.65452371 -0.12256964
# ...

# %%
import matplotlib.pyplot as plt
t = np.arange(100)
plt.plot(t,y.T)
x = 5
plt.title('Random stuff{}'.format(x))
# Out:
# Text(0.5,1,'Random stuff5')
